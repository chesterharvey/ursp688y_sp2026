# %% [markdown]
# Urban Data Science & Smart Cities <br>
# URSP688Y Spring 2026<br>
# Instructor: Chester Harvey <br>
# Urban Studies & Planning <br>
# National Center for Smart Growth <br>
# University of Maryland

# %% [markdown]
# # Exercise04
#
# This last exercise is an opportunity for you to get started on your final project. Please identify a portion of your project to get started on and submit a notebook (and any other related files) where you:
#
# 1. State the question you are aiming to address with this portion of your analysis
# 2. Outline the approach you will use to answer that question (pseudocode or you can start to more formally outline the approach section for your final narrative)
# 3. Operationalize your approach with data and code that you can later slot into your final analysis
#
# ## Submitting
#
# Please make a pull request with all of your code and reasonably-sized data in a folder named with your first name. See my example file structure in the `exercise04` directory:
#
# ```
# exercises
# └── exercise04
#     └── chester
#         ├── example_ReadMe.md
#         ├── exercise04_chester.ipynb
#         ├── example_module.py
#         └── example_data.csv
# ```
#
# If you have datasets that are too large for GitHub or should not be made public, please upload them to the [Google Drive folder for final project data](https://drive.google.com/drive/folders/1jgLIxx1B67nD4PekfDJnUI5jmrqa4iZm). Please also provide instructions for how someone running your code should properly locate or connect to these files so the analysis will run properly. For example, should they copy and paste the files into the same directory as your notebook, or a provided `data` directory? Best practice is to include these instructions in a separate ReadMe.md or ReadMe.txt file, or at the top of your notebook.

# %% [markdown]
# Research Question
#
# What are the current land values around some of the capital intensive stations on the Purple line ?
# What is the value capture gap from state property taxes to the value created around the stations?
#
# Approach and reasoning
#
# The goal is to predict the increased value using the methods from an already existing study. Taking that value difference and comparing to the capital cost of the these specific purple line stations. The purple line is not being funded by direct taxation of land around stations but , this is a useful examination of public goods and the land owners benefiting from the positive externalities. The study depending on results could be used to argue for future projects and using TIFs as a way of funding them in the future.
#
# Three stations have been picked  to have estimated cost the method has not been determined yet. Ive have found a few sources and trying to find a more accurate one. There might be two cost estimates.
# Geojson have md tax data has been found without names
# Taking the three stations and using the 3 catchment area distances from those stations making circles turn the geojson of all of prince georges county sdata and make it only in those circles Add to the data a row with the expected value increase from the station by the three catchment zones
# Create a difference column
# Normalize that value by number of households, lot size, and improvement size
# Create maps of catchment areas and parcels ( this might be a map showing which parcel has lowest improved value highest property gain).
# Create tables and graphics of the normalized data and the value increase compared to the station capital.
# Create interactive map of the color path maps of largest winners in value around the purple line to the station cost,  showing the intensity of improvements near them and who is paying the highest improvement value tax currently currently around those stations.
#
# Once I settle on a method of consgtucion cost calculaiton  I will make the csv and add with proper file format like shown above
#
# Data
#
# I will make a folder and might actually do api with this for repeatedly . Theres instructions on the maryland website which I will try and follow in order to get it to read more than 1000 lines at once.
# https://drive.google.com/file/d/1BGMHs61J82lDuN2kRoulx7VI3sI9pX0F/view?usp=drive_link
